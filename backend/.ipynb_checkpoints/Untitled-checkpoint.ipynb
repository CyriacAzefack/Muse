# %%
# shows a user's playlists (need to be authenticated via oauth)

import sys
import spotipy
import spotipy.util as util

def show_tracks(tracks):
    for i, item in enumerate(tracks['items']):
        track = item['track']
        print ("   %d %32.32s %s" % (i, track['artists'][0]['name'],
            track['name']))


if __name__ == '__main__':
    username = 'marshallerikson'
    token = util.prompt_for_user_token(username, scope='user-top-read')

    if token:
        sp = spotipy.Spotify(auth=token)
        playlists = sp.user_playlists(username)
        for playlist in playlists['items']:
            if playlist['owner']['id'] == username:
                print()
                print(playlist['name'])
                print( '  total tracks', playlist['tracks']['total'])
                results = sp.user_playlist(username, playlist['id'],
                    fields="tracks,next")
                tracks = results['tracks']
                show_tracks(tracks)
                while tracks['next']:
                    tracks = sp.next(tracks)
                    show_tracks(tracks)
    else:
        print( "Can't get token for", username)
# Out:
# Sélection
#   total tracks 5
#    0                      The Killers Human
#    1                        blink-182 Love Is Dangerous
#    2                      Ray Charles Hit The Road Jack
#    3                      Fatboy Slim Right Here, Right Now
#    4                             Zedd Ignite - 2016 League Of Legends World Championship
#
# a
#   total tracks 18
#    0                  Imagine Dragons Radioactive
#    1 Edward Sharpe & The Magnetic Zer Home
#    2                       Aloe Blacc I Need A Dollar
#    3                          Placebo Running Up That Hill
#    4                      The Killers Human
#    5                              M83 Midnight City
#    6                           Fergie A Little Party Never Killed Nobody (All We Got)
#    7                        Nightwish Storytime - Radio Edit
#    8                           Noisia Tommy's Theme - Original Mix
#    9                         Kid Cudi Solo Dolo (nightmare)
#    10                            Rusko Everyday - Netsky Remix
#    11                       Shaka Ponk My Name Is Stain
#    12         Electric Light Orchestra Mr Blue Sky
#    13 Edward Sharpe & The Magnetic Zer Home
#    14             The TV Theme Players Firefly
#    15                      The Killers Human
#    16                           P.O.D. Youth Of The Nation
#    17                       Pink Floyd Welcome To The Machine - 2011 Remastered Version
#
# Nightwish – Storytime
#   total tracks 1
#    0                        Nightwish Storytime - Radio Edit
#
# aaaaaa
#   total tracks 18
#    0                           Noisia Tommy's Theme - Original Mix
#    1                           Noisia Could This Be - Original MIx
#    2                         Kid Cudi Solo Dolo (nightmare)
#    3                         Modestep Sunlight
#    4                         Modestep Show Me A Sign
#    5                            Rusko Everyday - Netsky Remix
#    6                         Gorillaz Feel Good Inc
#    7                         Gorillaz On Melancholy Hill
#    8                         Gorillaz DARE
#    9                         Gorillaz Clint Eastwood
#    10                         Gorillaz Stylo (feat. Mos Def and Bobby Womack)
#    11                           Noisia My World - Original Mix
#    12                           Noisia Machine Gun - Original Mix
#    13                       Shaka Ponk My Name Is Stain
#    14                       Shaka Ponk I'm Picky
#    15                       Shaka Ponk Let's Bang
#    16                       Aloe Blacc I Need A Dollar
#    17              Swedish House Mafia Don't You Worry Child (Radio Edit) [feat. John Martin]
#
# tttt
#   total tracks 14
#    0                         Pendulum The Island - Pt. I (Dawn)
#    1                           Datsik Juicebox
#    2                         Skrillex Skrillex Orchestral Suite By Varien - Bonus Track
#    3              Swedish House Mafia Don't You Worry Child (Radio Edit) [feat. John Martin]
#    4           Emerson, Lake & Palmer Jerusalem
#    5                    Fort Atlantic Let Your Heart Hold Fast
#    6              Swedish House Mafia Save the World - Radio Mix
#    7              Swedish House Mafia Greyhound
#    8                  Imagine Dragons Radioactive
#    9              Swedish House Mafia Don't You Worry Child (feat. John Martin)
#    10                         Coldplay Every Teardrop Is a Waterfall - Coldplay vs. Swedish House Mafia
#    11         Electric Light Orchestra Mr Blue Sky
#    12 Edward Sharpe & The Magnetic Zer Home
#    13                    ItaloBrothers So Small - Radio Edit
#
# Midnight City
#   total tracks 4
#    0                              M83 Midnight City
#    1                    Gloria Gaynor I Will Survive - Remastered
#    2     Crosby, Stills, Nash & Young Our House
#    3                    Janet Jackson Control
