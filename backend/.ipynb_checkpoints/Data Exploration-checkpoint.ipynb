# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# <h1>Import the data</h1>

# %%
tracks_df = pd.read_csv('tracks.csv')
features_df = pd.read_csv('tracks_features.csv')
features_df.rename(columns={'id': 'track_id'}, inplace=True)

featured_tracks = tracks_df.merge(features_df, on='track_id', how='inner')

# %%
featured_tracks.head()
# Out:
#                  track_id                           title  \
# 0  4iK0yULrceBlRGBYww7A1E                           Amina
# 1  6UkpaWKK4hYUXC2x4lsuJU                    Woju (Remix)
# 2  2B3FCVxi308OK2z8suLD7r  Afro Trap Pt. 4 (Fais le mouv)
# 3  6eB0OjBglqL9KmouIfJ9hn                  Maman j’ai mal
# 4  66mNivkwO5D16jIajJ5phZ  Afro Trap Pt. 5 (Ngatie Abedi)
#
#                 artist_id  popularity  duration_ms_x  like  danceability  \
# 0  4WnAHZz1pgl8hus8hidIRV        50.0       204626.0   1.0         0.790
# 1  6eev6LNl6SEAKqLIo7vd9D        43.0       204210.0   1.0         0.791
# 2  4WnAHZz1pgl8hus8hidIRV        58.0       155706.0   1.0         0.952
# 3  4WnAHZz1pgl8hus8hidIRV        59.0       203680.0   1.0         0.723
# 4  4WnAHZz1pgl8hus8hidIRV        62.0       154946.0   1.0         0.888
#
#    energy   key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0   0.902   1.0    -5.757   1.0       0.0876        0.1290          0.000000
# 1   0.906   7.0    -2.705   1.0       0.0478        0.3020          0.000003
# 2   0.758   7.0    -4.628   1.0       0.2660        0.0181          0.000007
# 3   0.701   0.0    -7.363   0.0       0.1360        0.6100          0.000000
# 4   0.828  11.0    -3.535   0.0       0.0787        0.5260          0.000000
#
#    liveness  valence    tempo  duration_ms_y  time_signature
# 0    0.1320    0.785   93.766       204627.0             3.0
# 1    0.0356    0.970  113.955       204211.0             4.0
# 2    0.0447    0.849  126.981       155707.0             4.0
# 3    0.1880    0.534  116.019       203680.0             4.0
# 4    0.1070    0.768  127.996       154947.0             4.0

# %% [markdown]
# <h1>Data Preparation</h1>
# Perform some scaling on the data to have everything well distributed

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

num_col = features_df.describe().columns
scaled_features_df = features_df
scaled_features_df[num_col] = pd.DataFrame(scaler.fit_transform(scaled_features_df[num_col]), columns=num_col)

scaled_features_df.head()
# Out:
#                  track_id  danceability    energy       key  loudness  mode  \
# 0  4iK0yULrceBlRGBYww7A1E      0.764877  0.858647  0.090909  0.690484   1.0
# 1  6UkpaWKK4hYUXC2x4lsuJU      0.766328  0.864662  0.636364  0.858361   1.0
# 2  2B3FCVxi308OK2z8suLD7r      1.000000  0.642105  0.636364  0.752585   1.0
# 3  6eB0OjBglqL9KmouIfJ9hn      0.667634  0.556391  0.000000  0.602145   0.0
# 4  66mNivkwO5D16jIajJ5phZ      0.907112  0.747368  1.000000  0.812706   0.0
#
#    speechiness  acousticness  instrumentalness  liveness   valence     tempo  \
# 0     0.158704      0.141372          0.000000  0.129398  0.790755  0.182368
# 1     0.049423      0.331324          0.000003  0.019977  0.988257  0.317665
# 2     0.648545      0.019605          0.000008  0.030306  0.859080  0.404959
# 3     0.291598      0.669505          0.000000  0.192963  0.522793  0.331497
# 4     0.134267      0.577274          0.000000  0.101022  0.772606  0.411761
#
#    duration_ms  time_signature
# 0     0.185953             0.0
# 1     0.184982             0.5
# 2     0.071692             0.5
# 3     0.183741             0.5
# 4     0.069916             0.5

# %% [markdown]
# <h2>Distances between tracks</h2>

# %%
from scipy.spatial.distance import squareform, pdist
dist_df = pd.DataFrame(squareform(pdist(scaled_features_df.ix[:, 1:])), columns=scaled_features_df.track_id.unique(),
             index=scaled_features_df.track_id.unique())

liked_tracks_id = tracks_df[tracks_df.like == 1]['track_id']
#On the colums, we keep only the song the user like
dist_df = dist_df[liked_tracks_id]

#On the rows, we drop the song we like
dist_df = dist_df.drop(liked_tracks_id)

#On the rows, we have the new tracks and on the column, we have the song the user like

#dist_df['overall_dist'] = dist_df.quantile(q=0.2, axis=1)
dist_df['overall_dist'] = dist_df.mean(axis=1)

dist_df.sort_values(['overall_dist'], ascending=True, inplace=True)
dist_df.head()
#sns.heatmap(data=dist_df, cmap="YlGnBu")
# Out:
#                         4iK0yULrceBlRGBYww7A1E  6UkpaWKK4hYUXC2x4lsuJU  \
# 2f4cgNrOtiN7VUxu3Dnziw                0.799102                0.486933
# 1vBzd0jlsXdbkcah5NTRGh                0.872705                0.349131
# 247ZfUqi8jh9a4U629uQrX                0.861899                0.383676
# 4F53vz6YY7LLTXlmQQqC9h                0.947251                0.405921
# 6leKqvSviIydDluSDB7gQz                0.834377                0.584583
#
#                         2B3FCVxi308OK2z8suLD7r  6eB0OjBglqL9KmouIfJ9hn  \
# 2f4cgNrOtiN7VUxu3Dnziw                0.484471                1.399365
# 1vBzd0jlsXdbkcah5NTRGh                0.604554                1.411104
# 247ZfUqi8jh9a4U629uQrX                0.750848                1.414739
# 4F53vz6YY7LLTXlmQQqC9h                0.761860                1.458066
# 6leKqvSviIydDluSDB7gQz                0.496073                1.386824
#
#                         66mNivkwO5D16jIajJ5phZ  0deXVyvt3sUw813RtOQy01  \
# 2f4cgNrOtiN7VUxu3Dnziw                1.227802                0.852200
# 1vBzd0jlsXdbkcah5NTRGh                1.148942                0.816222
# 247ZfUqi8jh9a4U629uQrX                1.173206                0.970310
# 4F53vz6YY7LLTXlmQQqC9h                1.126634                1.041449
# 6leKqvSviIydDluSDB7gQz                1.268837                0.826009
#
#                         0v9yrgq9lNv5RJ3NPkCxmg  410olNFklIex3RgsmUgWuo  \
# 2f4cgNrOtiN7VUxu3Dnziw                1.224934                1.025055
# 1vBzd0jlsXdbkcah5NTRGh                1.139999                0.914382
# 247ZfUqi8jh9a4U629uQrX                1.221631                0.984613
# 4F53vz6YY7LLTXlmQQqC9h                1.241226                0.983785
# 6leKqvSviIydDluSDB7gQz                1.225781                0.993233
#
#                         6B06Inx97HC77t4y0wHxux  0J5yZ8WhWPyNnDYg1EWN4J  \
# 2f4cgNrOtiN7VUxu3Dnziw                0.715387                1.191409
# 1vBzd0jlsXdbkcah5NTRGh                0.672616                1.193770
# 247ZfUqi8jh9a4U629uQrX                0.649197                1.209313
# 4F53vz6YY7LLTXlmQQqC9h                0.754143                1.200690
# 6leKqvSviIydDluSDB7gQz                0.763937                1.221244
#
#                             ...       0bBXpeBxFLRCLAzbmd7cbM  \
# 2f4cgNrOtiN7VUxu3Dnziw      ...                     0.676538
# 1vBzd0jlsXdbkcah5NTRGh      ...                     0.708772
# 247ZfUqi8jh9a4U629uQrX      ...                     0.750644
# 4F53vz6YY7LLTXlmQQqC9h      ...                     0.804568
# 6leKqvSviIydDluSDB7gQz      ...                     0.725284
#
#                         1FkWnltHMW1mDxRapOsMMd  4C6kfMCoUimaW1dqHVy033  \
# 2f4cgNrOtiN7VUxu3Dnziw                1.721070                0.823632
# 1vBzd0jlsXdbkcah5NTRGh                1.729439                0.765166
# 247ZfUqi8jh9a4U629uQrX                1.755842                0.830726
# 4F53vz6YY7LLTXlmQQqC9h                1.784769                1.044098
# 6leKqvSviIydDluSDB7gQz                1.674485                0.777265
#
#                         0udOlv0R9AiEft5rucfo03  06B0pbiRWZJAfxJXu6R4wY  \
# 2f4cgNrOtiN7VUxu3Dnziw                0.691971                1.093473
# 1vBzd0jlsXdbkcah5NTRGh                0.686848                1.110628
# 247ZfUqi8jh9a4U629uQrX                0.601354                1.141387
# 4F53vz6YY7LLTXlmQQqC9h                0.660523                1.099762
# 6leKqvSviIydDluSDB7gQz                0.663864                1.033384
#
#                         0B1X6jlzNv6rUWmdDBOG9S  0GHHH0v6Q6WT2mhAgnUC1v  \
# 2f4cgNrOtiN7VUxu3Dnziw                1.003714                1.271938
# 1vBzd0jlsXdbkcah5NTRGh                0.834868                1.274961
# 247ZfUqi8jh9a4U629uQrX                0.909248                1.282260
# 4F53vz6YY7LLTXlmQQqC9h                0.784530                1.279255
# 6leKqvSviIydDluSDB7gQz                1.010062                1.259481
#
#                         0xOCWFZiMkOBGIWvgEKfWD  6KjIPqQlgf2jetOWtF6Zs8  \
# 2f4cgNrOtiN7VUxu3Dnziw                0.452457                0.830660
# 1vBzd0jlsXdbkcah5NTRGh                0.612440                0.583844
# 247ZfUqi8jh9a4U629uQrX                0.685400                0.626590
# 4F53vz6YY7LLTXlmQQqC9h                0.722862                0.570930
# 6leKqvSviIydDluSDB7gQz                0.482285                0.870097
#
#                         overall_dist
# 2f4cgNrOtiN7VUxu3Dnziw      0.499811
# 1vBzd0jlsXdbkcah5NTRGh      0.560372
# 247ZfUqi8jh9a4U629uQrX      0.561802
# 4F53vz6YY7LLTXlmQQqC9h      0.572237
# 6leKqvSviIydDluSDB7gQz      0.578656
#
# [5 rows x 50 columns]

# %%
#Get the 10 best tracks
best_tracks_id = dist_df.head(20).index

tracks_df[tracks_df.track_id.isin(best_tracks_id)]
# Out:
#                    track_id                                            title  \
# 58   5czvDLUDDQLIrU9RsyFooq                                             Napo
# 62   4Cd2DY6EjV8aqI9sjVdJk6                                          Jambole
# 75   6leKqvSviIydDluSDB7gQz                                        Kele Kele
# 80   2v3l2JMdEy88igmezrkzQp                                       Sytia Loss
# 92   4h3NiCORd1xcXUYxps2Uks                                          Folarin
# 118  1vBzd0jlsXdbkcah5NTRGh                                    Kadondo Style
# 121  4F53vz6YY7LLTXlmQQqC9h                                    Rouler moutou
# 148  6DPIMsoageIVwsUV4VZVlv                                       Toi et moi
# 168  43F5evseGamQ5ZXPBjdjv6                                   Letter To TINA
# 191  2bPaCYSYW8MWmA5xbjJdMA  C'est pas possible (feat. Youness) - Radio Edit
# 196  3PHTWeFEhSebB93KcM02Vi                               Mouille Le Maillot
# 200  3eXCiBrIfUg2IPzNtOgDUq                                    Triste destin
# 210  11nIA64PPmG6WVcRONm1hE                                             Ando
# 212  0cEri7Nlk88QmeScmWXzll                                             Roma
# 216  1aj6wMbUFHqnt5k6yVi34m                                 Girlie 'O' Remix
# 217  0TDFU3SY7Z7l74c7M7kJFO                Kiss Your Hand (feat. Wande Coal)
# 218  247ZfUqi8jh9a4U629uQrX                                        Happy Day
# 222  5uqQGd5RPl5NbCg7gOfUW6                                    Sentiment Awa
# 242  2f4cgNrOtiN7VUxu3Dnziw                                  Omo Wobe Anthem
# 244  3qVapNRZ2uM4Y2XSBNe0Np                                       Workaholic
#
#                   artist_id  popularity  duration_ms  like
# 58   6eev6LNl6SEAKqLIo7vd9D        29.0     194455.0   0.0
# 62   3eTpitQsrNQdmkQJHS2v2j        30.0     194063.0   0.0
# 75   1hNaHKp2Za5YdOAG0WnRbc        32.0     222693.0   0.0
# 80   5BfpzKNakWiXUNm1RfBgUi        23.0     211987.0   0.0
# 92   1hNaHKp2Za5YdOAG0WnRbc        17.0     251240.0   0.0
# 118  3eTpitQsrNQdmkQJHS2v2j        36.0     234240.0   0.0
# 121  1Vgb3eqBF3DLP6FwY7MuB4        22.0     248600.0   0.0
# 148  2nded5zgVbSiKxdh70DoP7        11.0     199505.0   0.0
# 168  374sWpAJsbZckf98df2jJJ        28.0     244801.0   0.0
# 191  1Cy58GZRk3TYmX0pb6pExg        33.0     179685.0   0.0
# 196  7cUFvbLZrLySXBoxk39kCZ         0.0     214440.0   0.0
# 200  1nsZMNRP1vmtIat8hD4bHg         5.0     227160.0   0.0
# 210  1mKorwTSYxVNbzBHCyX9Bf         1.0     299293.0   0.0
# 212  6voVBz1bN1mWZCLpNZGqzD        11.0     202080.0   0.0
# 216  7AV4NB11YbVRolNZclpaIb        42.0     235514.0   0.0
# 217  0LFsP7WPfu5inz9a1amcE4        30.0     268213.0   0.0
# 218  2hKQc001G7ggs3ZyxMdkGq        31.0     260146.0   0.0
# 222  0OHdN2jAGEqxSKBQQIs54k        13.0     203493.0   0.0
# 242  4ovtyvs7j1jSmwhkBGHqSr        35.0     187246.0   0.0
# 244  2s187JqHC9kipPLBLWXubl        25.0     196650.0   0.0

# %% [markdown]
# We have the reduce the dist matrix. We should only see the distance between the song we like and the others

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-708e83bb7a24> in <module>()
#       4
#       5 #On the rows, we drop the song we like
# ----> 6 dist_df = dist_df.drop(liked_tracks_id)
#       7
#       8 #On the rows, we have the new tracks and on the column, we have the song the user like
#
# C:\Users\i327247\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, level, inplace, errors)
#    1875                 new_axis = axis.drop(labels, level=level, errors=errors)
#    1876             else:
# -> 1877                 new_axis = axis.drop(labels, errors=errors)
#    1878             dropped = self.reindex(**{axis_name: new_axis})
#    1879             try:
#
# C:\Users\i327247\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\indexes\base.py in drop(self, labels, errors)
#    3049             if errors != 'ignore':
#    3050                 raise ValueError('labels %s not contained in axis' %
# -> 3051                                  labels[mask])
#    3052             indexer = indexer[~mask]
#    3053         return self.delete(indexer)
#
# ValueError: labels ['4iK0yULrceBlRGBYww7A1E' '6UkpaWKK4hYUXC2x4lsuJU' '2B3FCVxi308OK2z8suLD7r'
#  '6eB0OjBglqL9KmouIfJ9hn' '66mNivkwO5D16jIajJ5phZ' '0deXVyvt3sUw813RtOQy01'
#  '0v9yrgq9lNv5RJ3NPkCxmg' '410olNFklIex3RgsmUgWuo' '6B06Inx97HC77t4y0wHxux'
#  '0J5yZ8WhWPyNnDYg1EWN4J' '2XT9mDhAtP0uoxBqJ8HF36' '3q6cDwOPDPZ9ZBvMrrfdwU'
#  '3FA1Ktv9lTUtFTwOXr6wMN' '3a1PoUzZS5L7tUN8e1W9A0' '1k8A2fQEwbO7yN5JWp7jQn'
#  '29umcFLM8LZvjBS9lTlLQk' '41bp03eAj9ZuYbGNkCkkg3' '0ban5QRXUveaKtQPGuaoQ9'
#  '6Nh2UEWq9mI3iIWIR8L8n2' '3ePRRiOYaYuFjbdjbAxeh4' '67VH1BYRIMjGj3fZQBHDS2'
#  '5iL9eHXCoetboTwcQGz4Oy' '0h1UKhueXm1YFLpQjzwv0E' '0NtK87XUpxAnrxncVh8xzs'
#  '2WLpYiWNYtHeS5izWhrh6Q' '3WjrpeXCi4lQBUjVLSlpmu' '14iHXsW6PMGtNhhhQqd7jH'
#  '2MjuGAGJAbv0wjn77g3s4L' '5Mgv97QW3dcwODgUrtmIlN' '1H6BCeydQQQjH8y8Cc9Xbz'
#  '1yGnWQboreZCHMfT1fNA6P' '4DUlmxfCl6jrZdYAdfoYD6' '4okdTLfW8dskRvzzlxnG4S'
#  '5a39V8NZADQeq7yxRJ8H7l' '4EcXepJeuWXZ8nYI0aiBHC' '4OrnVTYj3Od79lBiyFHg4p'
#  '7umarL2ppWxQkjcMhTS0tu' '6E42NBef4akzQdRfSsAfDz' '0fJbAoGJxzwszQdOs3LiTC'
#  '5irIgvabRfzByac6xFozD8' '0bBXpeBxFLRCLAzbmd7cbM' '1FkWnltHMW1mDxRapOsMMd'
#  '4C6kfMCoUimaW1dqHVy033' '0udOlv0R9AiEft5rucfo03' '06B0pbiRWZJAfxJXu6R4wY'
#  '0B1X6jlzNv6rUWmdDBOG9S' '0GHHH0v6Q6WT2mhAgnUC1v' '0xOCWFZiMkOBGIWvgEKfWD'
#  '6KjIPqQlgf2jetOWtF6Zs8'] not contained in axis
