# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# <h1>Import the data</h1>

# %%
tracks_df = pd.read_csv('tracks.csv')
features_df = pd.read_csv('tracks_features.csv')
features_df.rename(columns={'id': 'track_id'}, inplace=True)

featured_tracks = tracks_df.merge(features_df, on='track_id', how='inner')

# %%
featured_tracks.head()
# Out:
#                  track_id                      title               artist_id  \
# 0  5mhUPDWQH3s544WCsa0r9w                      Human  0C0XlULifJtAgn6ZNCW2eu
# 1  10ViidwjGLCfVtGPfdcszR                       Home  7giUHu5pv6YTZgSkxxCcgh
# 2  1Thv8uCYzyOFC7PME9J936  The Island - Pt. I (Dawn)  7MqnCTCAX6SsIYYdJCQj9B
# 3  0Yo8GhK9HEaeIZetPARrW9                Radioactive  53XhwfbYqKCa1cC15pYq2q
# 4  3ZH2HcN2Q5jXrsnRznS98E     Storytime - Radio Edit  2NPduAUeLVsfIauhRwuft1
#
#    popularity  duration_ms_x  like  danceability  energy   key  loudness  \
# 0        63.0       245360.0   1.0         0.547   0.837  10.0    -7.085
# 1        68.0       306320.0   1.0         0.545   0.590   2.0    -6.693
# 2        56.0       320173.0   1.0         0.578   0.893   9.0    -3.615
# 3        53.0       188120.0   1.0         0.460   0.799   9.0    -3.502
# 4        19.0       239173.0   1.0         0.480   0.975   5.0    -3.142
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0   1.0       0.0676      0.001120          0.000624    0.0937    0.571
# 1   1.0       0.0327      0.320000          0.000389    0.1240    0.125
# 2   0.0       0.0557      0.000062          0.006290    0.1470    0.370
# 3   1.0       0.0573      0.124000          0.000598    0.2880    0.266
# 4   0.0       0.0712      0.004850          0.000604    0.1210    0.530
#
#      tempo  duration_ms_y  time_signature
# 0  135.470       245360.0             4.0
# 1  111.739       306320.0             4.0
# 2  126.018       320173.0             4.0
# 3  136.260       188120.0             4.0
# 4  156.185       239173.0             4.0

# %% [markdown]
# <h1>Data Preparation</h1>
# Perform some scaling on the data to have everything well distributed

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

num_col = features_df.describe().columns
scaled_features_df = features_df
scaled_features_df[num_col] = pd.DataFrame(scaler.fit_transform(scaled_features_df[num_col]), columns=num_col)

scaled_features_df.head()
# Out:
#                  track_id  danceability    energy       key  loudness  mode  \
# 0  5mhUPDWQH3s544WCsa0r9w      0.501351  0.832668  0.909091  0.725104   1.0
# 1  10ViidwjGLCfVtGPfdcszR      0.498649  0.558954  0.181818  0.744960   1.0
# 2  1Thv8uCYzyOFC7PME9J936      0.543243  0.894725  0.818182  0.900871   0.0
# 3  0Yo8GhK9HEaeIZetPARrW9      0.383784  0.790559  0.818182  0.906595   1.0
# 4  3ZH2HcN2Q5jXrsnRznS98E      0.410811  0.985594  0.454545  0.924830   0.0
#
#    speechiness  acousticness  instrumentalness  liveness   valence     tempo  \
# 0     0.139402      0.001150          0.000658  0.072838  0.579278  0.590024
# 1     0.028326      0.330233          0.000410  0.105877  0.096907  0.423641
# 2     0.101528      0.000058          0.006635  0.130956  0.361886  0.523754
# 3     0.106620      0.127962          0.000631  0.284702  0.249405  0.595563
# 4     0.150859      0.004999          0.000637  0.102606  0.534934  0.735262
#
#    duration_ms  time_signature
# 0     0.382135             0.5
# 1     0.543116             0.5
# 2     0.579698             0.5
# 3     0.230979             0.5
# 4     0.365797             0.5

# %% [markdown]
# <h2>Distances between tracks</h2>

# %%
from scipy.spatial.distance import squareform, pdist
dist_df = pd.DataFrame(squareform(pdist(scaled_features_df.ix[:, 1:])), columns=scaled_features_df.track_id.unique(),
             index=scaled_features_df.track_id.unique())

liked_tracks_id = tracks_df[tracks_df.like == 1]['track_id']
#On the colums, we keep only the song the user like
dist_df = dist_df[liked_tracks_id]

#On the rows, we drop the song we like
dist_df = dist_df.drop(liked_tracks_id)

#On the rows, we have the new tracks and on the column, we have the song the user like

#dist_df['overall_dist'] = dist_df.quantile(q=0.2, axis=1)
dist_df['overall_dist'] = dist_df.mean(axis=1)

dist_df.sort_values(['overall_dist'], ascending=True, inplace=True)
dist_df.head()
#sns.heatmap(data=dist_df, cmap="YlGnBu")
# Out:
#                         5mhUPDWQH3s544WCsa0r9w  10ViidwjGLCfVtGPfdcszR  \
# 5G0dcveKXu0WqaZywtTWPg                1.117449                1.189017
# 2hl8lxRV5RLvXZhiG2yGxC                1.076793                1.247770
# 6nsLzJfvp5OLd4mgqUJkpq                1.129861                1.220161
# 2takcwOaAZWiXQijPHIx7B                1.025832                1.323398
# 7ec55GDkRIBmsI8XKrG1lu                1.048987                1.306546
#
#                         1Thv8uCYzyOFC7PME9J936  0Yo8GhK9HEaeIZetPARrW9  \
# 5G0dcveKXu0WqaZywtTWPg                0.504666                1.087378
# 2hl8lxRV5RLvXZhiG2yGxC                0.353710                1.091031
# 6nsLzJfvp5OLd4mgqUJkpq                0.555448                1.139106
# 2takcwOaAZWiXQijPHIx7B                0.277970                1.084573
# 7ec55GDkRIBmsI8XKrG1lu                0.338924                1.145833
#
#                         3ZH2HcN2Q5jXrsnRznS98E  36482hNESSwELpr9sS3NbE  \
# 5G0dcveKXu0WqaZywtTWPg                0.469002                0.612425
# 2hl8lxRV5RLvXZhiG2yGxC                0.390355                0.599233
# 6nsLzJfvp5OLd4mgqUJkpq                0.483184                0.614535
# 2takcwOaAZWiXQijPHIx7B                0.527561                0.658452
# 7ec55GDkRIBmsI8XKrG1lu                0.331288                0.594023
#
#                         0qnqsfFYgBo0sPHM2JmfTq  3FKmqPkNa8f1UIZuw3SSfV  \
# 5G0dcveKXu0WqaZywtTWPg                1.068343                0.752740
# 2hl8lxRV5RLvXZhiG2yGxC                1.059619                0.920812
# 6nsLzJfvp5OLd4mgqUJkpq                1.155997                0.635049
# 2takcwOaAZWiXQijPHIx7B                1.130817                0.837572
# 7ec55GDkRIBmsI8XKrG1lu                1.097972                0.906955
#
#                         6GyFP1nfCDB8lbD2bG0Hq9  5s0dPzEGFSuXlQxTrxIWYa  \
# 5G0dcveKXu0WqaZywtTWPg                0.571399                1.509676
# 2hl8lxRV5RLvXZhiG2yGxC                0.520823                1.483568
# 6nsLzJfvp5OLd4mgqUJkpq                0.673837                1.575227
# 2takcwOaAZWiXQijPHIx7B                0.321820                1.599992
# 7ec55GDkRIBmsI8XKrG1lu                0.574252                1.547155
#
#                             ...       20I8RduZC2PWMWTDCZuuAN  \
# 5G0dcveKXu0WqaZywtTWPg      ...                     0.605243
# 2hl8lxRV5RLvXZhiG2yGxC      ...                     0.696777
# 6nsLzJfvp5OLd4mgqUJkpq      ...                     0.628776
# 2takcwOaAZWiXQijPHIx7B      ...                     0.683888
# 7ec55GDkRIBmsI8XKrG1lu      ...                     0.642179
#
#                         0h1UKhueXm1YFLpQjzwv0E  32IMcJ5pQ71rOFD0bIdneJ  \
# 5G0dcveKXu0WqaZywtTWPg                0.269633                0.575130
# 2hl8lxRV5RLvXZhiG2yGxC                0.332272                0.468619
# 6nsLzJfvp5OLd4mgqUJkpq                0.410986                0.760540
# 2takcwOaAZWiXQijPHIx7B                0.458215                0.638370
# 7ec55GDkRIBmsI8XKrG1lu                0.465405                0.634631
#
#                         4q7XSM6laraTPDglxDqn28  0q6LuUqGLUiCPP1cbdwFs3  \
# 5G0dcveKXu0WqaZywtTWPg                1.174003                1.248005
# 2hl8lxRV5RLvXZhiG2yGxC                1.194398                1.271730
# 6nsLzJfvp5OLd4mgqUJkpq                1.140850                1.250653
# 2takcwOaAZWiXQijPHIx7B                1.174160                1.324684
# 7ec55GDkRIBmsI8XKrG1lu                1.148427                1.271003
#
#                         1KQADAb1WscjfKMMF5JMFD  35BjsiYKNkMA3JPZFXjgXt  \
# 5G0dcveKXu0WqaZywtTWPg                1.183668                1.583937
# 2hl8lxRV5RLvXZhiG2yGxC                1.217612                1.531986
# 6nsLzJfvp5OLd4mgqUJkpq                1.125305                1.686923
# 2takcwOaAZWiXQijPHIx7B                1.187652                1.590044
# 7ec55GDkRIBmsI8XKrG1lu                1.160525                1.616248
#
#                         3rN3NK7KO1NiI1j79L5Bi8  3ChV0OY2OMofstepo4uVXy  \
# 5G0dcveKXu0WqaZywtTWPg                1.284489                0.492888
# 2hl8lxRV5RLvXZhiG2yGxC                1.299894                0.545742
# 6nsLzJfvp5OLd4mgqUJkpq                1.246569                0.416035
# 2takcwOaAZWiXQijPHIx7B                1.398525                0.487003
# 7ec55GDkRIBmsI8XKrG1lu                1.261196                0.563622
#
#                         overall_dist
# 5G0dcveKXu0WqaZywtTWPg      0.965438
# 2hl8lxRV5RLvXZhiG2yGxC      0.975736
# 6nsLzJfvp5OLd4mgqUJkpq      0.982643
# 2takcwOaAZWiXQijPHIx7B      0.983675
# 7ec55GDkRIBmsI8XKrG1lu      0.988261
#
# [5 rows x 48 columns]

# %%
#Get the 10 best tracks
best_tracks_id = dist_df.head(20).index

tracks_df[tracks_df.track_id.isin(best_tracks_id)]
# Out:
#                    track_id                                title  \
# 47   0kYUrLVQOfx21xuXu7OGrT      All These Things That I've Done
# 50   4prEPl61C8qZpeo3IkYSMl                           Sleepyhead
# 51   4VbDJMkAX3dWNBdn3KH6Wx                          Helena Beat
# 54   2takcwOaAZWiXQijPHIx7B                  Time Is Running Out
# 63   12HB8AmFTovKrFcGG36KbL                              Delilah
# 70   3HreJkWbRih4QPnIMJQK1i                          The Riddler
# 82   7ec55GDkRIBmsI8XKrG1lu                           Disco 2000
# 107  2hl8lxRV5RLvXZhiG2yGxC  Sing - Yellow Claw & Cesqeaux Remix
# 113  2K7j4xrQENCi5r3Hii4cVe       Shatter Me Featuring Lzzy Hale
# 123  7pPoBydlANHqWDYgm2DkSK                              Cloud 9
# 156  4hiUYb2nb6NlfTP9CD38Pe                            On My Way
# 157  6nsLzJfvp5OLd4mgqUJkpq                     Waiting For Love
# 159  6C6MLXm77V9VH0v27oJRak                   Thinking About You
# 162  0VYQK5I08homNvX8SRS37R                 Heroes (we could be)
# 166  0WZLWRN2rZMme7RxGbtdns                           If I Could
# 169  3tIzHV035ggENOtDQBfdTd                           Dirty Love
# 172  4BggEwLhGfrbrl7JBhC8EC                            Butterfly
# 193  12d4zn7xPYuzLuvOdVHqF8                                 Stop
# 200  5G0dcveKXu0WqaZywtTWPg                             Anomalie
# 219  0PITyfwD0Vlp5IzQXnIrkB        La fille du coupeur de joints
#
#                   artist_id  popularity  duration_ms  like
# 47   0C0XlULifJtAgn6ZNCW2eu        63.0     301573.0   0.0
# 50   7gjAu1qr5C2grXeQFFOGeh        64.0     174760.0   0.0
# 51   7gP3bB2nilZXLfPHJhMdvc        63.0     276173.0   0.0
# 54   12Chz98pHFMPJEknJQMWvI        63.0     237039.0   0.0
# 63   1moxjboGR7GNWYIMWsRjgG        58.0     293468.0   0.0
# 70   2NPduAUeLVsfIauhRwuft1        29.0     315960.0   0.0
# 82   36E7oYfz3LLRto6l2WmDcD        56.0     273733.0   0.0
# 107  5zYJziKktyqWwmoAWXrShP        41.0     243216.0   0.0
# 113  378dH6EszOLFShpRzAQkVM        57.0     280799.0   0.0
# 123  1feoGrmmD8QmNqtK2Gdwy8        55.0     277577.0   0.0
# 156  2o5jDhtHVPhrJdv3cEQ99Z        73.0     183710.0   0.0
# 157  1vCWHaC5f2uS3yhpwWbIA6        73.0     230613.0   0.0
# 159  6BrvowZBreEkXzJQMpL174        73.0     191311.0   0.0
# 162  4AVFqumd2ogHFlRbKIjp1t        65.0     209866.0   0.0
# 166  2N8IPNZTiNo3nj4mreOlHU        45.0     232462.0   0.0
# 169  6m8itYST9ADjBIYevXSb1r        47.0     223639.0   0.0
# 172  4iSKnRZAxkmqNok6tv10Se        66.0     216733.0   0.0
# 193  6RXZaVIbZfdngXJOSGrVH3        42.0     193266.0   0.0
# 200  4CAsSAU842glNKJX71ndA9        40.0     189520.0   0.0
# 219  5uD9sDsgIlcyH0e6Hkxbat        36.0     232760.0   0.0

# %% [markdown]
# We have the reduce the dist matrix. We should only see the distance between the song we like and the others
